# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score 
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import precision_recall_curve, confusion_matrix, roc_curve

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv('Pandas-Demo/data/data.csv')

# %% [markdown]
# # Pandas Interview Tasks

# %% [markdown]
# # Task 1: Calculate revenue growth rate for each user

# %%
df['revenue_growth_rate'] = df.groupby('user_id')['revenue'].transform(lambda x: 
                                                                       round((x - x.shift(1)) / x.shift(1) * 100, 2)).fillna(0).map(lambda x: 
                                                                                                                                    f"{x}%" if x < 0 else f"+{x}%")

# %% [markdown]
# # Task 2: Find users with three consecutive revenue increases followed by a decline

# %%
df['revenue_diff'] = df.groupby('user_id')['revenue'].diff()
def get_trend(x):
    if pd.isna(x) or x == 0:
        return 0
    return 1 if x > 0 else -1
df['trend'] = df['revenue_diff'].apply(get_trend)
df['t_0'] = df['trend']
df['t_1'] = df.groupby('user_id')['trend'].shift(-1)
df['t_2'] = df.groupby('user_id')['trend'].shift(-2)
df['t_3'] = df.groupby('user_id')['trend'].shift(-3)

df[(df['t_0'] == 1) & 
    (df['t_1'] == 1) & 
    (df['t_2'] == 1) & 
    (df['t_3'] == -1)]
# Out:
#     employee_id  user_id country        date  revenue    salary department  \
# 8             9     1008     USA  2026-01-09    513.0   59830.0    Finance
# 22           23     1010     USA  2026-01-23    538.0  137888.0    Finance
#
#     feature_1  feature_2  feature_3  target revenue_growth_rate  revenue_diff  \
# 8   -0.418509  -2.704901   5.181507       0             +165.8%         320.0
# 22  -2.216761  -0.619486   4.128753       0            +210.98%         365.0
#
#     trend  t_0  t_1  t_2  t_3
# 8       1    1  1.0  1.0 -1.0
# 22      1    1  1.0  1.0 -1.0

# %% [markdown]
# # Task 3: Calculate cumulative average revenue by country

# %%
df['avg_revenue'] = df.groupby('country')['revenue'].transform(lambda x: x.rolling(window=7, min_periods=1).mean())

# %% [markdown]
# # Task 4: Find the day with the largest revenue increase

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(by = 'date')
daily_df = df.groupby('date')['revenue'].sum().reset_index()
daily_df['revenue_growth'] = daily_df['revenue'] - daily_df['revenue'].shift()
ind = daily_df['revenue_growth'].idxmax()
daily_df.loc[ind, 'date']
# Out:
# Timestamp('2026-02-15 00:00:00')

# %% [markdown]
# # Task 5: Calculate days since the previous purchase

# %%
df = df.sort_values(by = ['user_id', 'date'])
df['day'] = df['date'].dt.day
df['days_since_previous_purchase'] = df.groupby('user_id')['day'].transform(lambda x: x - x.shift()).fillna('first_purchase')

# %% [markdown]
# # Task 6: Find users in the top 5% of revenue within each country

# %%
a = df.groupby(['user_id', 'country'])['revenue'].last().reset_index()
res = a.loc[a['revenue'] > a.groupby('country')['revenue'].transform(lambda x: x.quantile(0.95))] 
res
# Out:
#     user_id  country  revenue
# 2      1001       UK    850.0
# 17     1005   Canada    760.0
# 19     1005  Germany    946.0
# 21     1006   France    978.0
# 43     1010      USA    965.0

# %% [markdown]
# # Numpy Interview Tasks

# %% [markdown]
# # Create a NumPy feature matrix

# %%
feature_cols = ['feature_1', 'feature_2', 'feature_3']
a = df[feature_cols].values

# %% [markdown]
# # Task 1: Find the top 3 rows with the largest row sums

# %%
b = a.sum(axis = 1)
res_1 = b[np.argpartition(b, -3)[-3:]]
res_1
# Out:
# array([10.26734221, 10.31839415, 10.34932949])

# %% [markdown]
# # Task 2: Compute the correlation of every column with the last column

# %%
matrix_corr = np.corrcoef(a.T)
res_2 = matrix_corr[-1,:]
res_2
# Out:
# array([0.0168487, 0.0365959, 1.       ])

# %% [markdown]
# # Task 3: Find rows where at least 80% of values are above their column means

# %%
res_3 = np.mean(a > a.mean(axis = 0, keepdims = True), axis = 1)
a[res_3 >= 0.8]
# Out:
# array([[-0.07873168,  2.07431693,  5.90186344],
#        [ 1.68801703,  3.05420252,  5.5761746 ],
#        [ 0.73317336,  2.99977735,  5.46451661],
#        [ 1.67529325,  2.68417701,  5.90787195],
#        [ 0.05557216,  1.18748435,  5.81585162],
#        [ 0.4455069 ,  0.720338  ,  5.21586065],
#        [ 0.38279947,  2.87236694,  5.22333616],
#        [ 1.35881663,  0.15209608,  5.53191689],
#        [ 0.32451832,  0.8274256 ,  5.17396633],
#        [ 0.88620197,  3.22115693,  6.2419706 ],
#        [ 0.28988281,  1.73214103,  5.98749301],
#        [ 0.79059399,  1.61511126,  7.1728423 ],
#        [ 0.26763601,  0.98881857,  5.59540114],
#        [ 1.86077805,  1.29146558,  5.47682809],
#        [ 0.04560784,  1.23221331,  5.51612473],
#        [ 0.06023292,  2.42563015,  5.56675593],
#        [ 0.49214103,  0.51733382,  5.07526595],
#        [ 0.76157184,  1.12206613,  6.50502511],
#        [ 0.05741295,  0.08740534,  5.18351182],
#        [ 0.63285244,  1.84830477,  6.56281357],
#        [ 0.84357402,  0.10168514,  5.74236492]])

# %% [markdown]
# # Task 4: Standardize every feature using Z-score normalization

# %%
res_4 = (a - a.mean(axis = 0)) / a.std(axis = 0)
res_4
# Out:
# array([[ 9.63763608e-03,  1.03096968e+00,  8.43527570e-01],
#        [ 1.60921607e+00,  1.50380026e+00,  5.11849394e-01],
#        [ 3.06644030e-01, -5.19405270e-01, -1.16988998e-01],
#        [ 1.38805913e+00, -1.72572177e+00, -6.68215351e-01],
#        [ 7.44719989e-01,  1.47753813e+00,  3.98138037e-01],
#        [-2.14558405e+00,  1.64532523e+00, -1.33959857e+00],
#        [-1.78332620e-01,  3.70668176e-01,  6.34235938e-01],
#        [ 5.51874937e-02, -5.93690192e-01, -3.32491343e-01],
#        [ 1.28188023e+00, -1.63984461e+00,  4.04778168e-01],
#        [-2.14322987e+00, -1.27350930e+00,  2.04788934e+00],
#        [-1.89156169e-01, -7.21833293e-01,  1.01216551e+00],
#        [-1.13438309e+00,  2.84571959e-02, -2.19228329e+00],
#        [ 1.59769621e+00,  1.32524944e+00,  8.49646575e-01],
#        [ 1.31233608e-01,  6.03040583e-01,  7.55934017e-01],
#        [ 1.21073799e-01, -8.08208977e-01, -1.00134290e+00],
#        [ 4.84272611e-01,  3.77625413e-01,  1.44909358e-01],
#        [ 1.41929917e+00,  1.19985550e+00, -1.83630756e+00],
#        [-7.18601790e-01,  4.76598778e-01, -4.60949339e-01],
#        [ 1.50246599e+00, -1.57209852e+00, -1.73218602e-02],
#        [ 4.27498573e-01,  1.41605795e+00,  1.52522341e-01],
#        [ 1.05061896e+00, -4.37421893e-01, -1.29012479e+00],
#        [-9.25105459e-01,  2.47404587e-01, -4.73145936e-01],
#        [-2.29253304e-01,  9.34379438e-01,  1.13574185e+00],
#        [-4.16367505e-01, -6.96129992e-01, -5.92676331e-01],
#        [-6.83318304e-01,  1.06621757e+00,  2.84731190e-01],
#        [ 1.31116471e+00,  1.03427935e-01,  4.66777799e-01],
#        [ 5.03783789e-01, -6.47155698e-01, -1.25658403e+00],
#        [-1.31673794e+00, -7.40319256e-01, -5.07326491e-02],
#        [-1.30200490e+00,  1.21950225e+00, -9.66020778e-01],
#        [ 1.16291295e-02, -5.84942801e-01,  1.34156096e+00],
#        [-2.96486411e+00, -3.81116296e-01, -9.67907967e-02],
#        [ 3.74732002e-01,  4.29299088e-01,  1.02244612e-01],
#        [ 5.30046193e-01, -6.02169115e-01,  3.84791625e-01],
#        [ 8.83268978e-01,  1.58436186e+00,  1.18988922e+00],
#        [ 3.43373719e-01,  8.65857319e-01,  9.30731845e-01],
#        [ 4.85524972e-01, -5.49591355e-01, -9.91589480e-01],
#        [-1.99565944e-02, -5.08880414e-01, -8.64409032e-01],
#        [ 1.24154440e+00, -1.41043330e+00,  1.55156232e+00],
#        [ 4.87117108e-01,  1.67124736e-01, -4.39717495e-01],
#        [ 7.73062783e-01,  1.61165559e+00, -2.29163094e+00],
#        [ 7.96707457e-01,  8.09386182e-01,  2.13787942e+00],
#        [ 3.23231920e-01,  5.07177091e-01,  5.31429502e-01],
#        [ 1.76563039e+00,  6.53215321e-01,  4.10675931e-01],
#        [-7.15332628e-01, -1.08982069e-01,  1.18962786e+00],
#        [ 1.22212117e-01,  6.24623937e-01,  4.50695221e-01],
#        [-9.37588767e-01,  1.69743866e+00,  1.20701961e-01],
#        [-8.63356373e-01,  1.65588004e+00,  8.07869290e-01],
#        [ 1.33900486e+00, -1.09892284e+00, -3.05840209e-01],
#        [ 1.35453369e-01,  1.20049114e+00,  5.02257515e-01],
#        [-1.22233961e+00,  2.26055430e-01,  2.16318356e-01],
#        [-1.30670411e-01,  1.25953268e+00, -1.62261248e-01],
#        [ 5.16604469e-01,  1.41660921e+00, -1.31581828e+00],
#        [-9.55693448e-01, -2.67378207e-01,  4.98374294e-02],
#        [-5.52282986e-01, -9.74460386e-01, -1.15398546e+00],
#        [ 5.26494208e-01,  2.79668483e-01,  1.72915320e-03],
#        [-7.00074519e-01,  1.90652679e-01, -3.78508267e-01],
#        [-1.95994981e+00,  8.14501872e-01,  4.90937413e-01],
#        [ 1.09815163e+00,  1.26095120e+00, -7.03359465e-01],
#        [-1.49741538e+00,  2.42423822e-01, -6.17312015e-02],
#        [ 8.52252934e-01, -2.06888442e+00, -1.47913020e-01],
#        [-1.61179406e-01, -1.20553841e+00, -6.59225907e-01],
#        [-8.84506120e-01, -4.41537344e-01,  1.73012701e-01],
#        [ 1.11035220e+00, -1.08242785e-01, -1.17312442e-01],
#        [-2.97989742e-01, -1.27517753e+00,  1.09923931e-01],
#        [ 1.09213236e+00, -1.26108193e+00,  2.46519530e-01],
#        [-9.65260948e-01, -2.82042343e-01, -1.10765117e-01],
#        [-1.47309615e+00, -3.59423981e-01,  5.48569792e-02],
#        [ 2.02133418e+00, -5.83319122e-02, -1.35691275e+00],
#        [ 8.85788042e-01, -2.48763492e+00, -8.38731275e-02],
#        [-8.85899710e-02, -6.99224772e-02,  7.03337004e-01],
#        [-6.74405792e-02,  9.64833248e-01, -2.76524374e-01],
#        [-6.35887495e-01,  1.53605005e-01,  2.03013552e+00],
#        [ 5.83127302e-01, -1.67247527e+00,  1.23717890e+00],
#        [-9.18820292e-01, -8.46302442e-01, -6.44956408e-01],
#        [ 7.70431393e-01,  5.71473904e-01,  1.45778124e+00],
#        [ 1.32900222e-01,  7.22122894e-02,  1.11965646e-01],
#        [-7.94683016e-01,  5.25061789e-01, -1.81359448e+00],
#        [ 1.77436354e+00, -7.41773534e-02, -8.60187548e-01],
#        [ 2.44333956e-01,  2.41081177e-01, -7.90391775e-01],
#        [ 6.53891457e-01,  9.21910562e-01,  1.51663241e+00],
#        [-4.52940024e-01, -6.03562360e-01, -2.11940762e+00],
#        [ 9.71834650e-01, -6.17551055e-01, -3.69620452e-01],
#        [ 1.04920334e+00, -1.78804912e+00, -9.66723542e-01],
#        [-1.35543226e+00, -1.07792080e+00, -1.50088609e+00],
#        [-3.01310941e-01, -5.51185194e-01,  1.58964986e-01],
#        [-1.65279856e+00,  9.12697138e-01,  1.90783524e-01],
#        [ 7.76558652e-01,  1.99120196e+00, -1.11756721e+00],
#        [ 8.44674504e-01,  7.91028153e-02,  6.81095910e-01],
#        [-5.54487942e-01, -2.04087246e+00,  7.60408943e-01],
#        [ 6.16285315e-01, -6.81637265e-01,  1.93483144e+00],
#        [-1.92609076e+00, -2.68888692e-01, -9.62189813e-01],
#        [-4.76110827e-01, -5.64242287e-01,  1.13655531e+00],
#        [-2.91454449e-01, -8.11607798e-01,  6.49616820e-01],
#        [ 1.74688146e-01,  3.54251094e-01, -1.51614866e+00],
#        [-2.66282118e-01,  7.78773271e-02,  1.74098293e+00],
#        [-9.83922243e-01,  1.42381120e-01,  5.75446867e-01],
#        [-1.24252510e+00,  1.68860992e+00,  1.66550276e+00],
#        [-9.80164353e-01, -4.34490635e-01, -2.05562716e+00],
#        [ 4.33274994e-01, -4.80221234e-01,  4.09316938e-01],
#        [-1.30959356e-02, -1.22610624e+00, -7.68183910e-01]])

# %% [markdown]
# # Task 5: Compute cosine similarity between all rows

# %%
dot_product = a @ a.T
norms = np.linalg.norm(a, axis = 1, keepdims = True)
norms_matrix = norms @ norms.T
res_5 = dot_product / norms_matrix
res_5
# Out:
# array([[1.        , 0.95038088, 0.8435898 , ..., 0.75570171, 0.86039542,
#         0.63692953],
#        [0.95038088, 1.        , 0.7339693 , ..., 0.5400547 , 0.76032829,
#         0.48096746],
#        [0.8435898 , 0.7339693 , 1.        , ..., 0.91820492, 0.99917744,
#         0.94792496],
#        ...,
#        [0.75570171, 0.5400547 , 0.91820492, ..., 1.        , 0.90678158,
#         0.91971167],
#        [0.86039542, 0.76032829, 0.99917744, ..., 0.90678158, 1.        ,
#         0.93490452],
#        [0.63692953, 0.48096746, 0.94792496, ..., 0.91971167, 0.93490452,
#         1.        ]], shape=(100, 100))

# %% [markdown]
# # ML Interview Tasks

# %% [markdown]
# # Split features and target

# %%
X = df.drop(columns = ['target'])
y = df['target']

# %% [markdown]
# # Split the dataset into training and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 42)

# %% [markdown]
# # Define numerical and categorical features

# %%
num_cols = [
    'revenue', 
    'salary', 
    'avg_revenue',
    'feature_1', 
    'feature_2', 
    'feature_3'
]

cat_cols = [
    'country', 
    'department'
]

# %% [markdown]
# # Apply preprocessing to numerical and categorical features

# %%
preprocessor = ColumnTransformer([
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(sparse_output=False, handle_unknown = 'ignore'), cat_cols)
])

# %% [markdown]
# # Define preprocessing pipelines

# %%
pipe_1 = Pipeline([ ('preprocessor', preprocessor), 
                  ('poly', PolynomialFeatures(degree = 2, include_bias = False)), 
                  ('model', LogisticRegression()) ])

pipe_2 = Pipeline([ ('preprocessor', preprocessor), 
                   ('model', RandomForestClassifier(random_state = 42)) ]) 

pipe_3 = Pipeline([ ('preprocessor', preprocessor), 
                   ('model', XGBClassifier()) ]) 
pipe_1.fit(X_train, y_train) # Train Logistic Regression model
pipe_2.fit(X_train, y_train) # Train Random Forest model
pipe_3.fit(X_train, y_train) # Train XGBClassifier model
preds_1 = pipe_1.predict(X_test)
preds_2 = pipe_2.predict(X_test)
preds_3 = pipe_3.predict(X_test)

# %% [markdown]
# # Compare models using cross-validation

# %%
scores_lr = cross_val_score(pipe_1, X, y, cv = 5, n_jobs = -1, scoring = 'accuracy') 
scores_rf = cross_val_score(pipe_2, X, y, cv = 5, n_jobs = -1, scoring = 'accuracy') 
scores_xgb = cross_val_score(pipe_3, X, y, cv = 5, n_jobs = -1, scoring = 'accuracy') 
scores_lr_2 = cross_val_score(pipe_1, X, y, cv = 5, n_jobs = -1, scoring = 'roc_auc') 
scores_rf_2 = cross_val_score(pipe_2, X, y, cv = 5, n_jobs = -1, scoring = 'roc_auc') 
scores_xgb_2 = cross_val_score(pipe_3, X, y, cv = 5, n_jobs = -1, scoring = 'roc_auc')

# %% [markdown]
# # Optimize the decision threshold

# %%
y_probs = pipe_1.predict_proba(X_test)[:,1] 
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_probs) 
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-10) 
best_idx_pr = np.argmax(f1_scores) 
best_threshold_pr = thresholds_pr[best_idx_pr] 
best_threshold_pr
# Out:
# np.float64(0.06666570767820923)

# %% [markdown]
# # Create feature-importance dataframe

# %%
features = pipe_2.named_steps['preprocessor'].get_feature_names_out()
importances = pipe_2.named_steps['model'].feature_importances_
f_a_df = pd.DataFrame({'features' : features, 'importances' : importances}).sort_values(by = 'importances', ascending = False)
f_a_df
# Out:
#                      features  importances
# 1                 num__salary     0.204250
# 4              num__feature_2     0.140795
# 0                num__revenue     0.127759
# 3              num__feature_1     0.118577
# 5              num__feature_3     0.114176
# 2            num__avg_revenue     0.113758
# 10           cat__country_USA     0.046726
# 8        cat__country_Germany     0.024267
# 11    cat__department_Finance     0.022567
# 13         cat__department_IT     0.020874
# 15      cat__department_Sales     0.014550
# 7         cat__country_France     0.011425
# 14  cat__department_Marketing     0.011267
# 9             cat__country_UK     0.010986
# 6         cat__country_Canada     0.009739
# 12         cat__department_HR     0.008285

# %% [markdown]
# # Data Visualization Interview Tasks

# %% [markdown]
# # Task 1: Revenue Distribution by Country and Quarter

# %%
df['date'] = pd.to_datetime(df['date']) 
df['quarter'] = df['date'].dt.quarter 
sns.boxplot(data = df, x = 'country', y = 'revenue', hue = 'quarter')
# Out:
# <Axes: xlabel='country', ylabel='revenue'>

# %% [markdown]
# # Task 2: Actual vs predicted values

# %%
sns.scatterplot(x = range(len(y_test)), y = y_test.values, c = 'blue', alpha = 0.5, label = 'True Values', s = 100, marker = 'o') 
sns.scatterplot(x = range(len(y_test)), y = preds_1, c = 'red', label = 'Predictions', s = 50, marker = 'x')
# Out:
# <Axes: >

# %% [markdown]
# # Task 3: ROC curve

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_probs) 
sns.lineplot(x = fpr, y = tpr, c = 'red', lw = 2) 
plt.plot([0, 1], [0, 1], color="navy", lw=1.5, linestyle="--", alpha = 0.5) 
plt.xlim([0.0, 1.0]) 
plt.ylim([0.0, 1.05]) 
plt.show()

# %% [markdown]
# # Task 4: Feature Importance Analysis

# %%
features = pipe_3.named_steps['preprocessor'].get_feature_names_out() 
importances = pipe_3.named_steps['model'].feature_importances_ 
sns.barplot(y = features, x= importances)
# Out:
# <Axes: >

# %% [markdown]
# # Task 5: Dashboard(2x2):
# # 1. Salary Distribution (Histplot)
# # 2. Correlation Matrix (Heatmap)
# # 3. Departmental Breakdown (Boxplot)
# # 4. Top 15 Earners (Barplot)

# %%
fig, ax = plt.subplots(2, 2, figsize = (14, 8)) 
corr = df[num_cols].corr() 
sns.histplot(data = df, x = 'salary', ax = ax[0,0]) 
sns.heatmap(corr, annot = True, ax = ax[0,1]) 
sns.boxplot(data = df, x = 'department', y = 'salary', ax = ax[1,0]) 
top_earners = df.sort_values(by='salary', ascending=False).head(15)
sns.barplot(data = top_earners, y = 'salary', x = 'employee_id', ax = ax[1,1], order = top_earners['employee_id']) 
plt.tight_layout()

# %%
df
# Out:
#     employee_id  user_id  country       date  revenue    salary department  \
# 21           22     1001  Germany 2026-01-22    869.0   94045.0  Marketing
# 25           26     1001   France 2026-01-26    689.0   45600.0  Marketing
# 51           52     1001      USA 2026-02-21    209.0  106235.0    Finance
# 78           79     1001      USA 2026-03-20    202.0  106320.0  Marketing
# 83           84     1001   France 2026-03-25    387.0  145647.0         HR
# ..          ...      ...      ...        ...      ...       ...        ...
# 63           64     1010       UK 2026-03-05    722.0  106105.0  Marketing
# 65           66     1010  Germany 2026-03-07    677.0  140199.0         IT
# 75           76     1010      USA 2026-03-17    559.0   50729.0      Sales
# 93           94     1010  Germany 2026-04-04    326.0   48716.0  Marketing
# 95           96     1010      USA 2026-04-06    965.0  127545.0      Sales
#
#     feature_1  feature_2  feature_3  ...  revenue_diff trend  t_0  t_1  t_2  \
# 21  -0.078732   2.074317   5.901863  ...           NaN     0    0 -1.0 -1.0
# 25   1.688017   3.054203   5.576175  ...        -180.0    -1   -1 -1.0 -1.0
# 51   0.249315  -1.138652   4.958692  ...        -480.0    -1   -1 -1.0  1.0
# 78   1.443747  -3.638601   4.417419  ...          -7.0    -1   -1  1.0  1.0
# 83   0.733173   2.999777   5.464517  ...         185.0     1    1  1.0  1.0
# ..        ...        ...        ...  ...           ...   ...  ...  ...  ...
# 63  -1.176127   0.232822   5.638624  ...         269.0     1    1 -1.0 -1.0
# 65  -1.461757   3.437199   6.708996  ...         -45.0    -1   -1 -1.0 -1.0
# 75  -1.171977  -0.962677   3.055061  ...        -118.0    -1   -1 -1.0  1.0
# 93   0.389180  -1.057448   5.475494  ...        -233.0    -1   -1  1.0  NaN
# 95  -0.103841  -2.603207   4.319256  ...         639.0     1    1  NaN  NaN
#
#     t_3  avg_revenue  day  days_since_previous_purchase  quarter
# 21 -1.0   461.714286   22                first_purchase        1
# 25  1.0   662.600000   26                           4.0        1
# 51  1.0   487.000000   21                          -5.0        1
# 78  1.0   369.714286   20                          -1.0        1
# 83  NaN   526.428571   25                           5.0        1
# ..  ...          ...  ...                           ...      ...
# 63 -1.0   418.142857    5                           4.0        1
# 65  1.0   355.285714    7                           2.0        1
# 75  NaN   508.000000   17                          10.0        1
# 93  NaN   456.000000    4                         -13.0        2
# 95  NaN   560.000000    6                           2.0        2
#
# [100 rows x 22 columns]
